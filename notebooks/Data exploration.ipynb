# %%
import numpy as np
import matplotlib.pyplot as plt
from random import randint

# %%
# %matplotlib inline

# %%
# !pip install Pillow
# Out:
# ...
#      |████████████████████████████████| 2.0MB 622kB/s eta 0:00:01     |███████████████████████▏        | 1.4MB 622kB/s eta 0:00:01
# ...
# WARNING: You are using pip version 19.1, however version 19.1.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
image = plt.imread('../data/images/100.jpg')

# %%
image.shape
# Out:
# (256, 455, 3)

# %%
fig, ax = plt.subplots(2,3)
for a in ax.reshape(6): a.axis('off')
fig.set_size_inches(16,8)

for i in range(2):
    for j in range(3):
        random_value = randint(0,60000)
        image = plt.imread('../data/images/'+str(random_value)+'.jpg')
        ax[i,j].imshow(image)

# %%
training = !ls ../data/images
training_names = [name[:-4] for name in training[:3000]]

# %%
training_dict = {name: plt.imread('../data/images/'+f) for name, f in zip(training_names, training[:3000])}

# %%
np.savez_compressed('../data/training_data.npz', **training_dict)

# %%
del training_dict
